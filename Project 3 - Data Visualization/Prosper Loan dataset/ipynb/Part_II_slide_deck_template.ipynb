# %% [markdown]
# # Part II - Prosper Loan Dataset
# ## by Fesomade Alli

# %% [markdown]
# ## Investigation Overview
#
#
# > The goal is to assess the dataset for insights on the Prosper loan scheme. I would like to see what factors are likely to determine the sucess or failure of a loan application, the social status of those in need of loans, what are the loan requirements/conditions (for example borrower rates, collateral comditions, minimum salary range, bank credit status etc.)
#
#
# ## Dataset Overview
#
# > The dataset has 113,937 rows and 81 columns

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import time

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
path = r'C:\Users\Admin\Downloads\Stat Zone\jupyternotebookfiles\udacity-alx\quiz solutions\data-visualization\Prosper Loan dataset\dataset'
folder_dir = os.listdir(path)
r = re.compile(".*\.csv")
csv_file = list(filter(r.match, folder_dir)) 
print(csv_file)
# Out:
# ['prosperLoanData.csv']

# %%
filename = path + '\\' + csv_file[0]
start_time = time.time()
loan_df = pd.read_csv(filename)
end_time = time.time()
load_time = end_time - start_time
print('load time is ' + str(load_time))
# Out:
# load time is 4.13076376914978

# %% [markdown]
# ## Loan Application

# %% [markdown]
# ### Nature of Applicants
# > Majority of the applicants aren't neccessarily collar-job officers. Students are among those who get the least loan approvals and I'd argue it's because they likely make no income for a refund. With all the categories and their low count, I'd say the major part of the "Others" are likely to be business oriented personnels/bodies.
#
# > Applicants prefer medium to long term loan schemes and the commonest loan term is 36 Months
#
# > Majority of the applicants are from California

# %% [markdown]
# ## Loan Conditions & Applicant Status

# %% [markdown]
# ### Collateral
# > Well there are almost as many Non Home Owners are there are Home Owners.
# So, the idea of a collateral is quickly downtrodden.
# I presume it wont be a strong criteria.

# %% [markdown]
# ### Interest
# > The Borrower rate is mostly spread between 0.1 and 0.2 (the range where most values fall).
#
# > However, after adjusting the bin sizes, most values still seemed to distribute around the left and between .1 and .2
# but the highest count changes to just over the .3 margin.

# %% [markdown]
# ### Interest Per Loan Term
#
# > Although, the 36 Month loans have some outliers and a fairly higher median (in terms of the Borrower Rates) than the 12 month offers.
#
# > The long term loan schemes however have their interest rates around closer to the .2 margin and are most preferred by the applicants

# %% [markdown]
# ### Interest Per Employment Status
#
# > Most beneficiaries are employed but less than half have full time employments and even way lesser are self-employed.
#
# > This could likely correspond with my assumption of business oriented personnels because, if someone works a job part time,
# they likely need funds for their side-hustles/other business to look after families and mortgages and all.
#
# > Plus, having a means of employment is a strong criteria for obtaining loans as one would likely assume
# due to the need for a refund with interest

# %% [markdown]
# ### Interest Per Income Range
# > The common/median salary range happen to appear on the rightmost parts where the highest rates are with the low earners of the median range having the most people.
#
# > The higher percentage of those with the lower rates are often found with high income earners.

# %% [markdown]
# ## Loan Repayment

# %% [markdown]
# ### Quickest Refunds?
# > Though the columns analysed is missing a time information of refund dates of some sort but we can look at the completed loans and their interst rates and tell what's common
#
# > Completed loans have a relatively lower BorrowerRate with a decent amount of outliers
#
# > Those who are also in line of making final payment also have their median rates not so far from the .2 mark
#
# > There are definitely other things but can peg it at just the interest rates for now

# %% [markdown]
# ### Best Moving Loan Schemes?
# > 36 Month loan schemes is looking like the 'moving' business for the Propser Loan company

# %%
# Use this command if you are running this file in local
# !jupyter nbconvert Part_II_slide_deck_template.ipynb --to slides --post serve --no-input --no-prompt

# %% [markdown]
# > In the classroom workspace, the generated HTML slideshow will be placed in the home folder.
#
# > In local machines, the command above should open a tab in your web browser where you can scroll through your presentation. Sub-slides can be accessed by pressing 'down' when viewing its parent slide. Make sure you remove all of the quote-formatted guide notes like this one before you finish your presentation! At last, you can stop the Kernel.

# %% [markdown]
# ### Submission
# If you are using classroom workspace, you can choose from the following two ways of submission:
#
# 1. **Submit from the workspace**. Make sure you have removed the example project from the /home/workspace directory. You must submit the following files:
#    - Part_I_notebook.ipynb
#    - Part_I_notebook.html or pdf
#    - Part_II_notebook.ipynb
#    - Part_I_slides.html
#    - README.md
#    - dataset (optional)
#
#
# 2. **Submit a zip file on the last page of this project lesson**. In this case, open the Jupyter terminal and run the command below to generate a ZIP file.
# ```bash
# zip -r my_project.zip .
# ```
# The command abobve will ZIP every file present in your /home/workspace directory. Next, you can download the zip to your local, and follow the instructions on the last page of this project lesson.

# %% [markdown]
# ## Thank You
